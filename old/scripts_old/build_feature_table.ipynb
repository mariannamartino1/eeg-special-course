# %% [markdown]
# ### Build feature table
#
# This is the true dataset that will be used for the analysis.
#
# | participant_id | age | condition  | alpha_power_8_12 | fooof_alpha_cf | fooof_alpha_pw | fooof_alpha_bw | n_epochs_kept | fooof_r2 | fooof_error |
# | -------------- | --: | ---------- | ---------------: | -------------: | -------------: | -------------: | ------------: | -------: | ----------: |
# | sub-001        |  24 | EyesClosed |             1.82 |           10.4 |           0.61 |            2.3 |            85 |     0.97 |        0.03 |
# | sub-001        |  24 | EyesOpen   |             0.95 |           10.1 |           0.22 |            2.0 |            82 |     0.95 |        0.05 |

# %% [markdown]
# #### Imports and paths

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import mne
from fooof import FOOOF
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

PROJECT_ROOT = Path(r"C:\Users\maria\Desktop\EEG-special-course")
RAW_ROOT = PROJECT_ROOT / "data" / "ds005385"
PROCESSED_ROOT = PROJECT_ROOT / "data_processed"

manifest_file = PROCESSED_ROOT / "manifest_pre_ses1.csv"
out_file = PROCESSED_ROOT / "features_pre_ses1_with_posterior.csv"

manifest = pd.read_csv(manifest_file)
manifest.head()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_40584\2680078819.py:5: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF
#   participant_id  age                                   eyes_closed_file  \
# 0        sub-001   60  C:\Users\maria\Desktop\EEG-special-course\data...
# 1        sub-002   67  C:\Users\maria\Desktop\EEG-special-course\data...
# 2        sub-003   44  C:\Users\maria\Desktop\EEG-special-course\data...
# 3        sub-004   24  C:\Users\maria\Desktop\EEG-special-course\data...
# 4        sub-005   48  C:\Users\maria\Desktop\EEG-special-course\data...
#
#                                       eyes_open_file
# 0  C:\Users\maria\Desktop\EEG-special-course\data...
# 1  C:\Users\maria\Desktop\EEG-special-course\data...
# 2  C:\Users\maria\Desktop\EEG-special-course\data...
# 3  C:\Users\maria\Desktop\EEG-special-course\data...
# 4  C:\Users\maria\Desktop\EEG-special-course\data...

# %% [markdown]
# #### Define constants

# %%
OCCIPITAL_CHANNELS = ["O1", "Oz", "O2"]
ALPHA_BAND = (8.0, 12.0)

POSTERIOR_PREFIXES = ("P", "PO", "O")

RESAMPLE_FREQ = 250
FILTER_LO = 1.0
FILTER_HI = 40.0
NOTCH_FREQ = 50.0

EPOCH_LENGTH = 2.0
PTP_REJECT_VOLTS = 150e-6   # 150 microvolts
MIN_EPOCHS_REQUIRED = 10

# %% [markdown]
# #### Helper functions

# %%
def find_matching_channels_tsv(edf_path: str):
    edf_path = Path(edf_path)
    return edf_path.with_name(edf_path.name.replace("_eeg.edf", "_channels.tsv"))


def read_bad_channels(channels_tsv):
    channels_tsv = Path(channels_tsv)
    if not channels_tsv.exists():
        return []
    
    ch_df = pd.read_csv(channels_tsv, sep="\t")
    
    if "name" not in ch_df.columns or "status" not in ch_df.columns:
        return []
    
    bads = ch_df.loc[
        ch_df["status"].astype(str).str.lower() == "bad", "name"
    ].tolist()
    
    return bads


def preprocess_raw(edf_path: str):
    raw = mne.io.read_raw_edf(edf_path, preload=True, verbose="ERROR")
    raw.pick("eeg")
    
    # mark bad channels if available
    channels_tsv = find_matching_channels_tsv(edf_path)
    raw.info["bads"] = read_bad_channels(channels_tsv)
    
    # standard first-pass preprocessing
    raw.resample(RESAMPLE_FREQ, npad="auto")
    raw.filter(FILTER_LO, FILTER_HI, verbose="ERROR")
    raw.notch_filter(freqs=[NOTCH_FREQ], verbose="ERROR")
    raw.set_eeg_reference("average", verbose="ERROR")
    
    # IMPORTANT:
    # Do not pick only occipital channels here.
    # Keep all EEG channels so we can compute both:
    # 1) old occipital feature
    # 2) new posterior feature
    return raw

def get_occipital_channels(ch_names):
    return [ch for ch in OCCIPITAL_CHANNELS if ch in ch_names]


def get_posterior_channels(ch_names):
    posterior = []

    for ch in ch_names:
        ch_upper = ch.upper()

        if (
            ch_upper.startswith("P")
            or ch_upper.startswith("PO")
            or ch_upper.startswith("O")
        ):
            posterior.append(ch)

    return posterior


def make_clean_epochs(raw):
    epochs = mne.make_fixed_length_epochs(
        raw,
        duration=EPOCH_LENGTH,
        overlap=0.0,
        preload=True,
        verbose="ERROR"
    )
    
    data = epochs.get_data(copy=False)  # shape: epochs, channels, time
    ptp = np.ptp(data, axis=-1).max(axis=1)  # max peak-to-peak across channels
    keep_mask = ptp < PTP_REJECT_VOLTS
    
    epochs_clean = epochs[keep_mask]
    return epochs_clean


def compute_mean_psd(epochs, picks):
    spec = epochs.compute_psd(
        method="welch",
        fmin=2.0,
        fmax=30.0,
        picks=picks,
        verbose="ERROR"
    )

    psds, freqs = spec.get_data(return_freqs=True)  # epochs, channels, freqs

    # average across epochs and channels
    psd_mean = psds.mean(axis=(0, 1))

    return freqs, psd_mean

def compute_alpha_bandpower(freqs, psd, band=(8.0, 12.0)):
    mask = (freqs >= band[0]) & (freqs <= band[1])
    if mask.sum() == 0:
        return np.nan
    bp = np.trapz(psd[mask], freqs[mask])
    if bp <= 0:
        return np.nan
    return np.log10(bp)

def compute_alpha_sum_across_channels(epochs, picks, band=(8.0, 12.0)):
    if len(picks) == 0:
        return np.nan

    spec = epochs.compute_psd(
        method="welch",
        fmin=band[0],
        fmax=band[1],
        picks=picks,
        verbose="ERROR"
    )

    psds, freqs = spec.get_data(return_freqs=True)  # epochs, channels, freqs

    # Average across epochs, keeping channels separate
    psd_mean_per_channel = psds.mean(axis=0)        # channels, freqs

    # Integrate alpha power separately for each channel
    alpha_power_per_channel = np.trapz(
        psd_mean_per_channel,
        freqs,
        axis=1
    )

    # Sum alpha power across posterior channels
    alpha_sum = alpha_power_per_channel.sum()

    if alpha_sum <= 0:
        return np.nan

    return np.log10(alpha_sum)


def run_fooof(freqs, psd):
    fm = FOOOF(
        peak_width_limits=[1, 8],
        max_n_peaks=6,
        min_peak_height=0.05,
        peak_threshold=2.0,
        aperiodic_mode="fixed",
        verbose=False,
    )
    
    fm.fit(freqs, psd, [2, 30])
    
    peaks = fm.peak_params_
    if peaks is None or len(peaks) == 0:
        return np.nan, np.nan, np.nan, fm.r_squared_, fm.error_
    
    # keep peaks in an alpha-ish range
    alpha_peaks = peaks[(peaks[:, 0] >= 7.0) & (peaks[:, 0] <= 13.0)]
    
    if len(alpha_peaks) == 0:
        return np.nan, np.nan, np.nan, fm.r_squared_, fm.error_
    
    # choose strongest alpha peak
    best = alpha_peaks[np.argmax(alpha_peaks[:, 1])]
    cf, pw, bw = best
    
    return cf, pw, bw, fm.r_squared_, fm.error_

# %% [markdown]
# #### Extract features for one recording

# %%
def extract_features_for_recording(edf_path, participant_id, age, condition):
    try:
        raw = preprocess_raw(edf_path)

        occipital_channels = get_occipital_channels(raw.ch_names)
        posterior_channels = get_posterior_channels(raw.ch_names)

        if len(occipital_channels) == 0:
            raise ValueError(f"No occipital channels found in {edf_path}")

        if len(posterior_channels) == 0:
            raise ValueError(f"No posterior channels found in {edf_path}")

        epochs = make_clean_epochs(raw)
        n_epochs_kept = len(epochs)

        base_result = {
            "participant_id": participant_id,
            "age": age,
            "condition": condition,
            "n_occipital_channels": len(occipital_channels),
            "n_posterior_channels": len(posterior_channels),
            "posterior_channels": ",".join(posterior_channels),
            "n_epochs_kept": n_epochs_kept,
        }
        
        if n_epochs_kept < MIN_EPOCHS_REQUIRED:
            return {
                **base_result,
                "alpha_power_8_12": np.nan,
                "posterior_alpha_sum_8_12": np.nan,
                "fooof_alpha_cf": np.nan,
                "fooof_alpha_pw": np.nan,
                "fooof_alpha_bw": np.nan,
                "fooof_r2": np.nan,
                "fooof_error": np.nan,
            }
        
        # Existing feature:
        # mean PSD across O1/Oz/O2, then alpha power
        freqs_occ, psd_occ = compute_mean_psd(
            epochs,
            picks=occipital_channels
        )

        alpha_power = compute_alpha_bandpower(
            freqs_occ,
            psd_occ,
            ALPHA_BAND
        )

        # New professor-requested feature:
        # alpha power summed across P/PO/O channels
        posterior_alpha_sum = compute_alpha_sum_across_channels(
            epochs,
            picks=posterior_channels,
            band=ALPHA_BAND
        )

        # FOOOF still uses occipital average PSD, same as before
        cf, pw, bw, r2, err = run_fooof(freqs_occ, psd_occ)
        
        return {
            **base_result,
            "alpha_power_8_12": alpha_power,
            "posterior_alpha_sum_8_12": posterior_alpha_sum,
            "fooof_alpha_cf": cf,
            "fooof_alpha_pw": pw,
            "fooof_alpha_bw": bw,
            "fooof_r2": r2,
            "fooof_error": err,
        }
    
    except Exception as e:
        return {
            "participant_id": participant_id,
            "age": age,
            "condition": condition,
            "n_occipital_channels": np.nan,
            "n_posterior_channels": np.nan,
            "posterior_channels": np.nan,
            "alpha_power_8_12": np.nan,
            "posterior_alpha_sum_8_12": np.nan,
            "fooof_alpha_cf": np.nan,
            "fooof_alpha_pw": np.nan,
            "fooof_alpha_bw": np.nan,
            "n_epochs_kept": np.nan,
            "fooof_r2": np.nan,
            "fooof_error": np.nan,
            "error": str(e),
        }

# %% [markdown]
# #### Build features table

# %%
import time

checkpoint_file = PROCESSED_ROOT / "features_pre_ses1_posterior_checkpoint.csv"

# If a checkpoint already exists, load it and skip completed participants
if checkpoint_file.exists():
    features_existing = pd.read_csv(checkpoint_file)
    completed_ids = set(features_existing["participant_id"].unique())
    print(f"Found checkpoint with {len(features_existing)} rows")
    print(f"Completed participants: {len(completed_ids)}")
else:
    features_existing = pd.DataFrame()
    completed_ids = set()
    print("No checkpoint found, starting fresh")

rows = []

# Keep only participants not already processed
manifest_todo = manifest[~manifest["participant_id"].isin(completed_ids)].copy()
manifest_todo = manifest_todo.reset_index(drop=True)

print(f"Participants remaining: {len(manifest_todo)}")

start_all = time.time()

for i, (_, row) in enumerate(manifest_todo.iterrows(), start=1):
    participant_id = row["participant_id"]
    age = row["age"] if "age" in row else np.nan

    ec_file = row["eyes_closed_file"]
    eo_file = row["eyes_open_file"]

    start_one = time.time()
    print(f"[{i}/{len(manifest_todo)}] Processing {participant_id} ...")

    ec_features = extract_features_for_recording(
        ec_file, participant_id, age, "EyesClosed"
    )
    eo_features = extract_features_for_recording(
        eo_file, participant_id, age, "EyesOpen"
    )

    rows.extend([ec_features, eo_features])

    # Save checkpoint after every participant
    features_new = pd.DataFrame(rows)
    features_combined = pd.concat([features_existing, features_new], ignore_index=True)
    features_combined.to_csv(checkpoint_file, index=False)

    elapsed_one = time.time() - start_one
    print(f"    done in {elapsed_one:.1f} s")

elapsed_all = time.time() - start_all
print(f"Finished remaining participants in {elapsed_all/60:.1f} min")

# Final combined table
if checkpoint_file.exists():
    features = pd.read_csv(checkpoint_file)
else:
    features = pd.DataFrame(rows)

features = features.sort_values(["participant_id", "condition"]).reset_index(drop=True)
features.head()
# Out:
# No checkpoint found, starting fresh
# Participants remaining: 608
# [1/608] Processing sub-001 ...
#     done in 3.0 s
# [2/608] Processing sub-002 ...
#     done in 2.4 s
# [3/608] Processing sub-003 ...
#     done in 2.1 s
# [4/608] Processing sub-004 ...
#     done in 2.1 s
# [5/608] Processing sub-005 ...
#     done in 1.9 s
# [6/608] Processing sub-006 ...
#     done in 1.8 s
# [7/608] Processing sub-007 ...
#     done in 1.9 s
# [8/608] Processing sub-008 ...
#     done in 1.8 s
# [9/608] Processing sub-009 ...
#     done in 2.1 s
# [10/608] Processing sub-010 ...
#     done in 2.3 s
# [11/608] Processing sub-011 ...
#     done in 2.1 s
# [12/608] Processing sub-012 ...
#     done in 2.2 s
# [13/608] Processing sub-013 ...
#     done in 2.0 s
# [14/608] Processing sub-014 ...
#     done in 2.0 s
# [15/608] Processing sub-015 ...
#     done in 2.0 s
# [16/608] Processing sub-016 ...
#     done in 2.0 s
# [17/608] Processing sub-017 ...
#     done in 2.1 s
# [18/608] Processing sub-018 ...
#     done in 2.0 s
# [19/608] Processing sub-019 ...
#     done in 1.9 s
# [20/608] Processing sub-020 ...
#     done in 2.0 s
# [21/608] Processing sub-021 ...
#     done in 2.0 s
# [22/608] Processing sub-022 ...
#     done in 2.0 s
# [23/608] Processing sub-023 ...
#     done in 2.0 s
# [24/608] Processing sub-024 ...
#     done in 2.0 s
# [25/608] Processing sub-025 ...
#     done in 2.1 s
# [26/608] Processing sub-026 ...
#     done in 2.0 s
# [27/608] Processing sub-027 ...
#     done in 2.0 s
# [28/608] Processing sub-028 ...
#     done in 2.1 s
# [29/608] Processing sub-029 ...
#     done in 2.0 s
# [30/608] Processing sub-030 ...
#     done in 2.0 s
# [31/608] Processing sub-031 ...
#     done in 2.0 s
# [32/608] Processing sub-032 ...
#     done in 2.0 s
# [33/608] Processing sub-033 ...
#     done in 2.0 s
# [34/608] Processing sub-034 ...
#     done in 2.0 s
# [35/608] Processing sub-035 ...
#     done in 2.1 s
# [36/608] Processing sub-036 ...
#     done in 2.0 s
# [37/608] Processing sub-037 ...
#     done in 2.1 s
# [38/608] Processing sub-038 ...
#     done in 2.2 s
# [39/608] Processing sub-039 ...
#     done in 2.0 s
# [40/608] Processing sub-040 ...
#     done in 2.1 s
# [41/608] Processing sub-041 ...
#     done in 2.0 s
# [42/608] Processing sub-042 ...
#     done in 2.0 s
# [43/608] Processing sub-043 ...
#     done in 2.0 s
# [44/608] Processing sub-044 ...
#     done in 2.1 s
# [45/608] Processing sub-045 ...
#     done in 2.0 s
# [46/608] Processing sub-046 ...
#     done in 2.1 s
# [47/608] Processing sub-047 ...
#     done in 2.0 s
# [48/608] Processing sub-048 ...
#     done in 2.0 s
# [49/608] Processing sub-049 ...
#     done in 2.0 s
# [50/608] Processing sub-050 ...
#     done in 2.1 s
# [51/608] Processing sub-051 ...
#     done in 2.1 s
# [52/608] Processing sub-052 ...
#     done in 2.0 s
# [53/608] Processing sub-053 ...
#     done in 2.1 s
# [54/608] Processing sub-054 ...
#     done in 2.1 s
# [55/608] Processing sub-055 ...
#     done in 2.1 s
# [56/608] Processing sub-056 ...
#     done in 2.1 s
# [57/608] Processing sub-057 ...
#     done in 2.3 s
# [58/608] Processing sub-058 ...
#     done in 2.2 s
# [59/608] Processing sub-059 ...
#     done in 2.2 s
# [60/608] Processing sub-060 ...
#     done in 2.0 s
# [61/608] Processing sub-061 ...
#     done in 2.2 s
# [62/608] Processing sub-062 ...
#     done in 2.1 s
# [63/608] Processing sub-063 ...
#     done in 2.1 s
# [64/608] Processing sub-064 ...
#     done in 2.2 s
# [65/608] Processing sub-065 ...
#     done in 2.0 s
# [66/608] Processing sub-066 ...
#     done in 2.5 s
# [67/608] Processing sub-067 ...
#     done in 2.2 s
# [68/608] Processing sub-068 ...
#     done in 2.1 s
# [69/608] Processing sub-069 ...
#     done in 2.1 s
# [70/608] Processing sub-070 ...
#     done in 2.2 s
# [71/608] Processing sub-071 ...
#     done in 2.2 s
# [72/608] Processing sub-072 ...
#     done in 2.3 s
# [73/608] Processing sub-073 ...
#     done in 2.1 s
# [74/608] Processing sub-074 ...
#     done in 2.6 s
# [75/608] Processing sub-075 ...
#     done in 2.6 s
# [76/608] Processing sub-076 ...
#     done in 2.5 s
# [77/608] Processing sub-077 ...
#     done in 2.3 s
# [78/608] Processing sub-078 ...
#     done in 2.6 s
# [79/608] Processing sub-079 ...
#     done in 2.6 s
# [80/608] Processing sub-080 ...
#     done in 2.0 s
# [81/608] Processing sub-081 ...
#     done in 2.2 s
# [82/608] Processing sub-082 ...
#     done in 2.2 s
# [83/608] Processing sub-083 ...
#     done in 2.4 s
# [84/608] Processing sub-084 ...
#     done in 2.0 s
# [85/608] Processing sub-085 ...
#     done in 2.5 s
# [86/608] Processing sub-086 ...
#     done in 2.3 s
# [87/608] Processing sub-087 ...
#     done in 2.1 s
# [88/608] Processing sub-088 ...
#     done in 2.1 s
# [89/608] Processing sub-089 ...
#     done in 2.1 s
# [90/608] Processing sub-090 ...
#     done in 2.2 s
# [91/608] Processing sub-091 ...
#     done in 2.1 s
# [92/608] Processing sub-092 ...
#     done in 2.6 s
# [93/608] Processing sub-093 ...
#     done in 2.2 s
# [94/608] Processing sub-094 ...
#     done in 2.2 s
# [95/608] Processing sub-095 ...
#     done in 2.2 s
# [96/608] Processing sub-096 ...
#     done in 2.1 s
# [97/608] Processing sub-097 ...
#     done in 2.2 s
# [98/608] Processing sub-098 ...
#     done in 2.2 s
# [99/608] Processing sub-099 ...
#     done in 2.9 s
# [100/608] Processing sub-100 ...
#     done in 2.2 s
# [101/608] Processing sub-101 ...
#     done in 3.1 s
# [102/608] Processing sub-102 ...
#     done in 2.5 s
# [103/608] Processing sub-103 ...
#     done in 2.7 s
# [104/608] Processing sub-104 ...
#     done in 2.3 s
# [105/608] Processing sub-105 ...
#     done in 2.2 s
# [106/608] Processing sub-106 ...
#     done in 2.0 s
# [107/608] Processing sub-107 ...
#     done in 2.1 s
# [108/608] Processing sub-108 ...
#     done in 2.3 s
# [109/608] Processing sub-109 ...
#     done in 2.2 s
# [110/608] Processing sub-110 ...
#     done in 2.1 s
# [111/608] Processing sub-111 ...
#     done in 2.7 s
# [112/608] Processing sub-112 ...
#     done in 2.6 s
# [113/608] Processing sub-113 ...
#     done in 2.2 s
# [114/608] Processing sub-114 ...
#     done in 2.0 s
# [115/608] Processing sub-115 ...
#     done in 1.9 s
# [116/608] Processing sub-116 ...
#     done in 2.3 s
# [117/608] Processing sub-117 ...
#     done in 2.3 s
# [118/608] Processing sub-118 ...
#     done in 2.1 s
# [119/608] Processing sub-119 ...
#     done in 2.0 s
# [120/608] Processing sub-120 ...
#     done in 2.1 s
# [121/608] Processing sub-121 ...
#     done in 2.2 s
# [122/608] Processing sub-122 ...
#     done in 2.3 s
# [123/608] Processing sub-123 ...
#     done in 3.1 s
# [124/608] Processing sub-124 ...
#     done in 3.6 s
# [125/608] Processing sub-125 ...
#     done in 3.4 s
# [126/608] Processing sub-126 ...
#     done in 3.1 s
# [127/608] Processing sub-127 ...
#     done in 2.1 s
# [128/608] Processing sub-128 ...
#     done in 2.4 s
# [129/608] Processing sub-129 ...
#     done in 2.6 s
# [130/608] Processing sub-130 ...
#     done in 2.3 s
# [131/608] Processing sub-131 ...
#     done in 2.5 s
# [132/608] Processing sub-132 ...
#     done in 4.8 s
# [133/608] Processing sub-133 ...
#     done in 3.8 s
# [134/608] Processing sub-134 ...
#     done in 3.6 s
# [135/608] Processing sub-135 ...
#     done in 2.7 s
# [136/608] Processing sub-136 ...
#     done in 2.2 s
# [137/608] Processing sub-137 ...
#     done in 2.3 s
# [138/608] Processing sub-138 ...
#     done in 2.1 s
# [139/608] Processing sub-139 ...
#     done in 2.2 s
# [140/608] Processing sub-140 ...
#     done in 2.1 s
# [141/608] Processing sub-141 ...
#     done in 2.1 s
# [142/608] Processing sub-142 ...
#     done in 2.1 s
# [143/608] Processing sub-143 ...
#     done in 2.3 s
# [144/608] Processing sub-144 ...
#     done in 2.1 s
# [145/608] Processing sub-145 ...
#     done in 2.9 s
# [146/608] Processing sub-146 ...
#     done in 2.5 s
# [147/608] Processing sub-147 ...
#     done in 2.4 s
# [148/608] Processing sub-148 ...
#     done in 2.4 s
# [149/608] Processing sub-149 ...
#     done in 2.6 s
# [150/608] Processing sub-150 ...
#     done in 2.7 s
# [151/608] Processing sub-151 ...
#     done in 2.3 s
# [152/608] Processing sub-152 ...
#     done in 2.2 s
# [153/608] Processing sub-153 ...
#     done in 2.2 s
# [154/608] Processing sub-154 ...
#     done in 2.2 s
# [155/608] Processing sub-155 ...
#     done in 2.1 s
# [156/608] Processing sub-156 ...
#     done in 2.2 s
# [157/608] Processing sub-157 ...
#     done in 2.3 s
# [158/608] Processing sub-158 ...
#     done in 2.2 s
# [159/608] Processing sub-159 ...
#     done in 2.2 s
# [160/608] Processing sub-160 ...
#     done in 2.3 s
# [161/608] Processing sub-161 ...
#     done in 2.2 s
# [162/608] Processing sub-162 ...
#     done in 2.1 s
# [163/608] Processing sub-163 ...
#     done in 2.2 s
# [164/608] Processing sub-164 ...
#     done in 2.6 s
# [165/608] Processing sub-165 ...
#     done in 2.3 s
# [166/608] Processing sub-166 ...
#     done in 2.4 s
# [167/608] Processing sub-167 ...
#     done in 2.0 s
# [168/608] Processing sub-168 ...
#     done in 2.3 s
# [169/608] Processing sub-169 ...
#     done in 2.6 s
# [170/608] Processing sub-170 ...
#     done in 2.6 s
# [171/608] Processing sub-171 ...
#     done in 2.6 s
# [172/608] Processing sub-172 ...
#     done in 2.3 s
# [173/608] Processing sub-173 ...
#     done in 2.2 s
# [174/608] Processing sub-174 ...
#     done in 2.3 s
# [175/608] Processing sub-175 ...
#     done in 2.3 s
# [176/608] Processing sub-176 ...
#     done in 2.5 s
# [177/608] Processing sub-177 ...
#     done in 2.6 s
# [178/608] Processing sub-178 ...
#     done in 2.4 s
# [179/608] Processing sub-179 ...
#     done in 2.3 s
# [180/608] Processing sub-180 ...
#     done in 2.3 s
# [181/608] Processing sub-181 ...
#     done in 2.8 s
# [182/608] Processing sub-182 ...
#     done in 2.4 s
# [183/608] Processing sub-183 ...
#     done in 2.6 s
# [184/608] Processing sub-184 ...
#     done in 2.1 s
# [185/608] Processing sub-185 ...
#     done in 2.6 s
# [186/608] Processing sub-186 ...
#     done in 2.4 s
# [187/608] Processing sub-187 ...
#     done in 2.1 s
# [188/608] Processing sub-188 ...
#     done in 2.3 s
# [189/608] Processing sub-189 ...
#     done in 2.3 s
# [190/608] Processing sub-190 ...
#     done in 2.8 s
# [191/608] Processing sub-191 ...
#     done in 2.3 s
# [192/608] Processing sub-192 ...
#     done in 2.7 s
# [193/608] Processing sub-193 ...
#     done in 2.6 s
# [194/608] Processing sub-194 ...
#     done in 2.7 s
# [195/608] Processing sub-195 ...
#     done in 2.1 s
# [196/608] Processing sub-196 ...
#     done in 2.4 s
# [197/608] Processing sub-197 ...
#     done in 2.2 s
# [198/608] Processing sub-198 ...
#     done in 2.0 s
# [199/608] Processing sub-199 ...
#     done in 2.4 s
# [200/608] Processing sub-200 ...
#     done in 2.6 s
# [201/608] Processing sub-201 ...
#     done in 2.3 s
# [202/608] Processing sub-202 ...
#     done in 2.6 s
# [203/608] Processing sub-203 ...
#     done in 2.3 s
# [204/608] Processing sub-204 ...
#     done in 2.6 s
# [205/608] Processing sub-205 ...
#     done in 2.3 s
# [206/608] Processing sub-206 ...
#     done in 2.5 s
# [207/608] Processing sub-207 ...
#     done in 2.4 s
# [208/608] Processing sub-208 ...
#     done in 2.1 s
# [209/608] Processing sub-209 ...
#     done in 2.3 s
# [210/608] Processing sub-210 ...
#     done in 2.3 s
# [211/608] Processing sub-211 ...
#     done in 2.1 s
# [212/608] Processing sub-212 ...
#     done in 2.4 s
# [213/608] Processing sub-213 ...
#     done in 2.2 s
# [214/608] Processing sub-214 ...
#     done in 4.4 s
# [215/608] Processing sub-215 ...
#     done in 2.1 s
# [216/608] Processing sub-216 ...
#     done in 2.4 s
# [217/608] Processing sub-217 ...
#     done in 2.3 s
# [218/608] Processing sub-218 ...
#     done in 2.3 s
# [219/608] Processing sub-219 ...
#     done in 2.5 s
# [220/608] Processing sub-220 ...
#     done in 2.2 s
# [221/608] Processing sub-221 ...
#     done in 2.5 s
# [222/608] Processing sub-222 ...
#     done in 2.5 s
# [223/608] Processing sub-223 ...
#     done in 2.6 s
# [224/608] Processing sub-224 ...
#     done in 2.4 s
# [225/608] Processing sub-225 ...
#     done in 2.6 s
# [226/608] Processing sub-226 ...
#     done in 2.9 s
# [227/608] Processing sub-227 ...
#     done in 2.3 s
# [228/608] Processing sub-228 ...
#     done in 2.5 s
# [229/608] Processing sub-229 ...
#     done in 2.7 s
# [230/608] Processing sub-230 ...
#     done in 1.8 s
# [231/608] Processing sub-231 ...
#     done in 2.5 s
# [232/608] Processing sub-232 ...
#     done in 2.4 s
# [233/608] Processing sub-233 ...
#     done in 2.3 s
# [234/608] Processing sub-234 ...
#     done in 2.1 s
# [235/608] Processing sub-235 ...
#     done in 2.3 s
# [236/608] Processing sub-236 ...
#     done in 2.2 s
# [237/608] Processing sub-237 ...
#     done in 2.2 s
# [238/608] Processing sub-238 ...
#     done in 2.2 s
# [239/608] Processing sub-239 ...
#     done in 2.4 s
# [240/608] Processing sub-240 ...
#     done in 2.1 s
# [241/608] Processing sub-241 ...
#     done in 2.2 s
# [242/608] Processing sub-242 ...
#     done in 2.3 s
# [243/608] Processing sub-243 ...
#     done in 2.1 s
# [244/608] Processing sub-244 ...
#     done in 3.0 s
# [245/608] Processing sub-245 ...
#     done in 2.5 s
# [246/608] Processing sub-246 ...
#     done in 2.6 s
# [247/608] Processing sub-247 ...
#     done in 2.7 s
# [248/608] Processing sub-248 ...
#     done in 2.8 s
# [249/608] Processing sub-249 ...
#     done in 2.8 s
# [250/608] Processing sub-250 ...
#     done in 2.7 s
# [251/608] Processing sub-251 ...
#     done in 2.6 s
# [252/608] Processing sub-252 ...
#     done in 2.7 s
# [253/608] Processing sub-253 ...
#     done in 3.0 s
# [254/608] Processing sub-254 ...
#     done in 2.6 s
# [255/608] Processing sub-255 ...
#     done in 2.5 s
# [256/608] Processing sub-256 ...
#     done in 2.4 s
# [257/608] Processing sub-257 ...
#     done in 2.7 s
# [258/608] Processing sub-258 ...
#     done in 2.4 s
# [259/608] Processing sub-259 ...
#     done in 2.7 s
# [260/608] Processing sub-260 ...
#     done in 2.7 s
# [261/608] Processing sub-261 ...
#     done in 2.3 s
# [262/608] Processing sub-262 ...
#     done in 2.2 s
# [263/608] Processing sub-263 ...
#     done in 2.4 s
# [264/608] Processing sub-264 ...
#     done in 2.3 s
# [265/608] Processing sub-265 ...
#     done in 2.2 s
# [266/608] Processing sub-266 ...
#     done in 2.9 s
# [267/608] Processing sub-267 ...
#     done in 2.4 s
# [268/608] Processing sub-268 ...
#     done in 2.5 s
# [269/608] Processing sub-269 ...
#     done in 2.2 s
# [270/608] Processing sub-270 ...
#     done in 2.3 s
# [271/608] Processing sub-271 ...
#     done in 3.2 s
# [272/608] Processing sub-272 ...
#     done in 2.4 s
# [273/608] Processing sub-273 ...
#     done in 2.2 s
# [274/608] Processing sub-274 ...
#     done in 2.2 s
# [275/608] Processing sub-275 ...
#     done in 2.4 s
# [276/608] Processing sub-276 ...
#     done in 2.5 s
# [277/608] Processing sub-277 ...
#     done in 2.2 s
# [278/608] Processing sub-278 ...
#     done in 2.3 s
# [279/608] Processing sub-279 ...
#     done in 2.3 s
# [280/608] Processing sub-280 ...
#     done in 2.1 s
# [281/608] Processing sub-281 ...
#     done in 2.2 s
# [282/608] Processing sub-282 ...
#     done in 2.0 s
# [283/608] Processing sub-283 ...
#     done in 2.2 s
# [284/608] Processing sub-284 ...
#     done in 2.3 s
# [285/608] Processing sub-285 ...
#     done in 2.7 s
# [286/608] Processing sub-286 ...
#     done in 2.3 s
# [287/608] Processing sub-287 ...
#     done in 2.2 s
# [288/608] Processing sub-288 ...
#     done in 2.1 s
# [289/608] Processing sub-289 ...
#     done in 2.2 s
# [290/608] Processing sub-290 ...
#     done in 2.3 s
# [291/608] Processing sub-291 ...
#     done in 2.1 s
# [292/608] Processing sub-292 ...
#     done in 2.0 s
# [293/608] Processing sub-293 ...
#     done in 2.3 s
# [294/608] Processing sub-294 ...
#     done in 2.4 s
# [295/608] Processing sub-295 ...
#     done in 2.1 s
# [296/608] Processing sub-296 ...
#     done in 2.1 s
# [297/608] Processing sub-297 ...
#     done in 2.2 s
# [298/608] Processing sub-298 ...
#     done in 2.1 s
# [299/608] Processing sub-299 ...
#     done in 2.3 s
# [300/608] Processing sub-300 ...
#     done in 2.3 s
# [301/608] Processing sub-301 ...
#     done in 2.1 s
# [302/608] Processing sub-302 ...
#     done in 2.1 s
# [303/608] Processing sub-303 ...
#     done in 2.3 s
# [304/608] Processing sub-304 ...
#     done in 2.2 s
# [305/608] Processing sub-305 ...
#     done in 2.3 s
# [306/608] Processing sub-306 ...
#     done in 2.3 s
# [307/608] Processing sub-307 ...
#     done in 2.0 s
# [308/608] Processing sub-308 ...
#     done in 2.3 s
# [309/608] Processing sub-309 ...
#     done in 2.1 s
# [310/608] Processing sub-310 ...
#     done in 2.2 s
# [311/608] Processing sub-311 ...
#     done in 2.2 s
# [312/608] Processing sub-312 ...
#     done in 2.1 s
# [313/608] Processing sub-313 ...
#     done in 2.3 s
# [314/608] Processing sub-314 ...
#     done in 2.2 s
# [315/608] Processing sub-315 ...
#     done in 2.2 s
# [316/608] Processing sub-316 ...
#     done in 2.1 s
# [317/608] Processing sub-317 ...
#     done in 2.2 s
# [318/608] Processing sub-318 ...
#     done in 2.2 s
# [319/608] Processing sub-319 ...
#     done in 1.9 s
# [320/608] Processing sub-320 ...
#     done in 2.2 s
# [321/608] Processing sub-321 ...
#     done in 2.5 s
# [322/608] Processing sub-322 ...
#     done in 2.2 s
# [323/608] Processing sub-323 ...
#     done in 2.1 s
# [324/608] Processing sub-324 ...
#     done in 2.1 s
# [325/608] Processing sub-325 ...
#     done in 2.1 s
# [326/608] Processing sub-326 ...
#     done in 2.1 s
# [327/608] Processing sub-327 ...
#     done in 2.2 s
# [328/608] Processing sub-328 ...
#     done in 2.0 s
# [329/608] Processing sub-329 ...
#     done in 2.1 s
# [330/608] Processing sub-330 ...
#     done in 2.3 s
# [331/608] Processing sub-331 ...
#     done in 2.1 s
# [332/608] Processing sub-332 ...
#     done in 2.1 s
# [333/608] Processing sub-333 ...
#     done in 2.2 s
# [334/608] Processing sub-334 ...
#     done in 2.1 s
# [335/608] Processing sub-335 ...
#     done in 3.8 s
# [336/608] Processing sub-336 ...
#     done in 2.0 s
# [337/608] Processing sub-337 ...
#     done in 2.1 s
# [338/608] Processing sub-338 ...
#     done in 2.1 s
# [339/608] Processing sub-339 ...
#     done in 2.3 s
# [340/608] Processing sub-340 ...
#     done in 2.1 s
# [341/608] Processing sub-341 ...
#     done in 2.2 s
# [342/608] Processing sub-342 ...
#     done in 2.1 s
# [343/608] Processing sub-343 ...
#     done in 2.1 s
# [344/608] Processing sub-344 ...
#     done in 2.2 s
# [345/608] Processing sub-345 ...
#     done in 2.1 s
# [346/608] Processing sub-346 ...
#     done in 2.2 s
# [347/608] Processing sub-347 ...
#     done in 2.2 s
# [348/608] Processing sub-348 ...
#     done in 2.3 s
# [349/608] Processing sub-349 ...
#     done in 2.1 s
# [350/608] Processing sub-350 ...
#     done in 2.2 s
# [351/608] Processing sub-351 ...
#     done in 2.2 s
# [352/608] Processing sub-352 ...
#     done in 2.1 s
# [353/608] Processing sub-353 ...
#     done in 2.1 s
# [354/608] Processing sub-354 ...
#     done in 2.9 s
# [355/608] Processing sub-355 ...
#     done in 2.1 s
# [356/608] Processing sub-356 ...
#     done in 2.0 s
# [357/608] Processing sub-357 ...
#     done in 2.4 s
# [358/608] Processing sub-358 ...
#     done in 2.2 s
# [359/608] Processing sub-359 ...
#     done in 2.2 s
# [360/608] Processing sub-360 ...
#     done in 2.2 s
# [361/608] Processing sub-361 ...
#     done in 2.2 s
# [362/608] Processing sub-362 ...
#     done in 2.2 s
# [363/608] Processing sub-363 ...
#     done in 2.1 s
# [364/608] Processing sub-364 ...
#     done in 2.1 s
# [365/608] Processing sub-365 ...
#     done in 2.2 s
# [366/608] Processing sub-366 ...
#     done in 2.2 s
# [367/608] Processing sub-367 ...
#     done in 2.1 s
# [368/608] Processing sub-368 ...
#     done in 2.3 s
# [369/608] Processing sub-369 ...
#     done in 2.3 s
# [370/608] Processing sub-370 ...
#     done in 2.4 s
# [371/608] Processing sub-371 ...
#     done in 2.5 s
# [372/608] Processing sub-372 ...
#     done in 2.2 s
# [373/608] Processing sub-373 ...
#     done in 2.3 s
# [374/608] Processing sub-374 ...
#     done in 2.0 s
# [375/608] Processing sub-375 ...
#     done in 2.2 s
# [376/608] Processing sub-376 ...
#     done in 2.2 s
# [377/608] Processing sub-377 ...
#     done in 2.1 s
# [378/608] Processing sub-378 ...
#     done in 2.2 s
# [379/608] Processing sub-379 ...
#     done in 2.2 s
# [380/608] Processing sub-380 ...
#     done in 2.2 s
# [381/608] Processing sub-381 ...
#     done in 2.1 s
# [382/608] Processing sub-382 ...
#     done in 2.2 s
# [383/608] Processing sub-383 ...
#     done in 2.1 s
# [384/608] Processing sub-384 ...
#     done in 2.1 s
# [385/608] Processing sub-385 ...
#     done in 2.2 s
# [386/608] Processing sub-386 ...
#     done in 2.5 s
# [387/608] Processing sub-387 ...
#     done in 2.2 s
# [388/608] Processing sub-388 ...
#     done in 2.0 s
# [389/608] Processing sub-389 ...
#     done in 2.3 s
# [390/608] Processing sub-390 ...
#     done in 2.1 s
# [391/608] Processing sub-391 ...
#     done in 2.2 s
# [392/608] Processing sub-392 ...
#     done in 2.2 s
# [393/608] Processing sub-393 ...
#     done in 2.2 s
# [394/608] Processing sub-394 ...
#     done in 2.2 s
# [395/608] Processing sub-395 ...
#     done in 2.2 s
# [396/608] Processing sub-396 ...
#     done in 2.2 s
# [397/608] Processing sub-397 ...
#     done in 2.6 s
# [398/608] Processing sub-398 ...
#     done in 2.6 s
# [399/608] Processing sub-399 ...
#     done in 2.1 s
# [400/608] Processing sub-400 ...
#     done in 2.0 s
# [401/608] Processing sub-401 ...
#     done in 2.1 s
# [402/608] Processing sub-402 ...
#     done in 2.1 s
# [403/608] Processing sub-403 ...
#     done in 2.1 s
# [404/608] Processing sub-404 ...
#     done in 2.1 s
# [405/608] Processing sub-405 ...
#     done in 2.1 s
# [406/608] Processing sub-406 ...
#     done in 2.1 s
# [407/608] Processing sub-407 ...
#     done in 2.2 s
# [408/608] Processing sub-408 ...
#     done in 2.1 s
# [409/608] Processing sub-409 ...
#     done in 2.2 s
# [410/608] Processing sub-410 ...
#     done in 2.1 s
# [411/608] Processing sub-411 ...
#     done in 2.1 s
# [412/608] Processing sub-412 ...
#     done in 2.1 s
# [413/608] Processing sub-413 ...
#     done in 2.2 s
# [414/608] Processing sub-414 ...
#     done in 2.2 s
# [415/608] Processing sub-415 ...
#     done in 2.2 s
# [416/608] Processing sub-416 ...
#     done in 2.2 s
# [417/608] Processing sub-417 ...
#     done in 2.1 s
# [418/608] Processing sub-418 ...
#     done in 2.2 s
# [419/608] Processing sub-419 ...
#     done in 2.2 s
# [420/608] Processing sub-420 ...
#     done in 2.2 s
# [421/608] Processing sub-421 ...
#     done in 2.1 s
# [422/608] Processing sub-422 ...
#     done in 2.5 s
# [423/608] Processing sub-423 ...
#     done in 2.2 s
# [424/608] Processing sub-424 ...
#     done in 2.1 s
# [425/608] Processing sub-425 ...
#     done in 2.3 s
# [426/608] Processing sub-426 ...
#     done in 2.2 s
# [427/608] Processing sub-427 ...
#     done in 2.0 s
# [428/608] Processing sub-428 ...
#     done in 2.1 s
# [429/608] Processing sub-429 ...
#     done in 2.2 s
# [430/608] Processing sub-430 ...
#     done in 2.1 s
# [431/608] Processing sub-431 ...
#     done in 2.1 s
# [432/608] Processing sub-432 ...
#     done in 2.1 s
# [433/608] Processing sub-433 ...
#     done in 2.1 s
# [434/608] Processing sub-434 ...
#     done in 2.1 s
# [435/608] Processing sub-435 ...
#     done in 2.1 s
# [436/608] Processing sub-436 ...
#     done in 2.1 s
# [437/608] Processing sub-437 ...
#     done in 2.1 s
# [438/608] Processing sub-438 ...
#     done in 2.0 s
# [439/608] Processing sub-439 ...
#     done in 2.1 s
# [440/608] Processing sub-440 ...
#     done in 2.1 s
# [441/608] Processing sub-441 ...
#     done in 2.1 s
# [442/608] Processing sub-442 ...
#     done in 2.1 s
# [443/608] Processing sub-443 ...
#     done in 2.1 s
# [444/608] Processing sub-444 ...
#     done in 2.0 s
# [445/608] Processing sub-445 ...
#     done in 2.1 s
# [446/608] Processing sub-446 ...
#     done in 2.2 s
# [447/608] Processing sub-447 ...
#     done in 2.2 s
# [448/608] Processing sub-448 ...
#     done in 2.0 s
# [449/608] Processing sub-449 ...
#     done in 2.1 s
# [450/608] Processing sub-450 ...
#     done in 2.1 s
# [451/608] Processing sub-451 ...
#     done in 2.1 s
# [452/608] Processing sub-452 ...
#     done in 2.1 s
# [453/608] Processing sub-453 ...
#     done in 2.1 s
# [454/608] Processing sub-454 ...
#     done in 2.1 s
# [455/608] Processing sub-455 ...
#     done in 2.1 s
# [456/608] Processing sub-456 ...
#     done in 2.2 s
# [457/608] Processing sub-457 ...
#     done in 2.1 s
# [458/608] Processing sub-458 ...
#     done in 2.1 s
# [459/608] Processing sub-459 ...
#     done in 2.1 s
# [460/608] Processing sub-460 ...
#     done in 2.1 s
# [461/608] Processing sub-461 ...
#     done in 2.1 s
# [462/608] Processing sub-462 ...
#     done in 2.2 s
# [463/608] Processing sub-463 ...
#     done in 2.2 s
# [464/608] Processing sub-464 ...
#     done in 2.1 s
# [465/608] Processing sub-465 ...
#     done in 2.1 s
# [466/608] Processing sub-466 ...
#     done in 2.1 s
# [467/608] Processing sub-467 ...
#     done in 2.0 s
# [468/608] Processing sub-468 ...
#     done in 2.1 s
# [469/608] Processing sub-469 ...
#     done in 2.1 s
# [470/608] Processing sub-470 ...
#     done in 2.1 s
# [471/608] Processing sub-471 ...
#     done in 2.2 s
# [472/608] Processing sub-472 ...
#     done in 2.2 s
# [473/608] Processing sub-473 ...
#     done in 2.1 s
# [474/608] Processing sub-474 ...
#     done in 2.5 s
# [475/608] Processing sub-475 ...
#     done in 2.1 s
# [476/608] Processing sub-476 ...
#     done in 2.1 s
# [477/608] Processing sub-477 ...
#     done in 2.0 s
# [478/608] Processing sub-478 ...
#     done in 2.0 s
# [479/608] Processing sub-479 ...
#     done in 2.1 s
# [480/608] Processing sub-480 ...
#     done in 2.1 s
# [481/608] Processing sub-481 ...
#     done in 2.1 s
# [482/608] Processing sub-482 ...
#     done in 2.1 s
# [483/608] Processing sub-483 ...
#     done in 2.1 s
# [484/608] Processing sub-484 ...
#     done in 2.1 s
# [485/608] Processing sub-485 ...
#     done in 2.1 s
# [486/608] Processing sub-486 ...
#     done in 2.1 s
# [487/608] Processing sub-487 ...
#     done in 2.2 s
# [488/608] Processing sub-488 ...
#     done in 2.1 s
# [489/608] Processing sub-489 ...
#     done in 2.2 s
# [490/608] Processing sub-490 ...
#     done in 2.1 s
# [491/608] Processing sub-491 ...
#     done in 2.1 s
# [492/608] Processing sub-492 ...
#     done in 2.1 s
# [493/608] Processing sub-493 ...
#     done in 2.1 s
# [494/608] Processing sub-494 ...
#     done in 2.7 s
# [495/608] Processing sub-495 ...
#     done in 2.1 s
# [496/608] Processing sub-496 ...
#     done in 2.1 s
# [497/608] Processing sub-497 ...
#     done in 2.1 s
# [498/608] Processing sub-498 ...
#     done in 2.2 s
# [499/608] Processing sub-499 ...
#     done in 2.2 s
# [500/608] Processing sub-500 ...
#     done in 2.1 s
# [501/608] Processing sub-501 ...
#     done in 2.1 s
# [502/608] Processing sub-502 ...
#     done in 2.2 s
# [503/608] Processing sub-503 ...
#     done in 2.1 s
# [504/608] Processing sub-504 ...
#     done in 2.1 s
# [505/608] Processing sub-505 ...
#     done in 2.1 s
# [506/608] Processing sub-506 ...
#     done in 2.0 s
# [507/608] Processing sub-507 ...
#     done in 2.1 s
# [508/608] Processing sub-508 ...
#     done in 2.2 s
# [509/608] Processing sub-509 ...
#     done in 2.1 s
# [510/608] Processing sub-510 ...
#     done in 2.2 s
# [511/608] Processing sub-511 ...
#     done in 2.1 s
# [512/608] Processing sub-512 ...
#     done in 2.1 s
# [513/608] Processing sub-513 ...
#     done in 2.1 s
# [514/608] Processing sub-514 ...
#     done in 2.1 s
# [515/608] Processing sub-515 ...
#     done in 2.0 s
# [516/608] Processing sub-516 ...
#     done in 2.1 s
# [517/608] Processing sub-517 ...
#     done in 2.1 s
# [518/608] Processing sub-518 ...
#     done in 2.2 s
# [519/608] Processing sub-519 ...
#     done in 2.1 s
# [520/608] Processing sub-520 ...
#     done in 2.1 s
# [521/608] Processing sub-521 ...
#     done in 2.2 s
# [522/608] Processing sub-522 ...
#     done in 2.1 s
# [523/608] Processing sub-523 ...
#     done in 2.2 s
# [524/608] Processing sub-524 ...
#     done in 2.1 s
# [525/608] Processing sub-525 ...
#     done in 2.1 s
# [526/608] Processing sub-526 ...
#     done in 2.4 s
# [527/608] Processing sub-527 ...
#     done in 2.2 s
# [528/608] Processing sub-528 ...
#     done in 2.2 s
# [529/608] Processing sub-529 ...
#     done in 2.1 s
# [530/608] Processing sub-530 ...
#     done in 2.2 s
# [531/608] Processing sub-531 ...
#     done in 2.0 s
# [532/608] Processing sub-532 ...
#     done in 2.2 s
# [533/608] Processing sub-533 ...
#     done in 2.1 s
# [534/608] Processing sub-534 ...
#     done in 2.0 s
# [535/608] Processing sub-535 ...
#     done in 2.1 s
# [536/608] Processing sub-536 ...
#     done in 2.1 s
# [537/608] Processing sub-537 ...
#     done in 2.1 s
# [538/608] Processing sub-538 ...
#     done in 2.2 s
# [539/608] Processing sub-539 ...
#     done in 2.1 s
# [540/608] Processing sub-540 ...
#     done in 2.1 s
# [541/608] Processing sub-541 ...
#     done in 2.0 s
# [542/608] Processing sub-542 ...
#     done in 2.2 s
# [543/608] Processing sub-543 ...
#     done in 2.4 s
# [544/608] Processing sub-544 ...
#     done in 2.2 s
# [545/608] Processing sub-545 ...
#     done in 2.1 s
# [546/608] Processing sub-546 ...
#     done in 2.0 s
# [547/608] Processing sub-547 ...
#     done in 2.1 s
# [548/608] Processing sub-548 ...
#     done in 2.2 s
# [549/608] Processing sub-549 ...
#     done in 2.1 s
# [550/608] Processing sub-550 ...
#     done in 2.1 s
# [551/608] Processing sub-551 ...
#     done in 2.1 s
# [552/608] Processing sub-552 ...
#     done in 2.1 s
# [553/608] Processing sub-553 ...
#     done in 2.0 s
# [554/608] Processing sub-554 ...
#     done in 2.1 s
# [555/608] Processing sub-555 ...
#     done in 2.2 s
# [556/608] Processing sub-556 ...
#     done in 3.6 s
# [557/608] Processing sub-557 ...
#     done in 2.0 s
# [558/608] Processing sub-558 ...
#     done in 2.1 s
# [559/608] Processing sub-559 ...
#     done in 2.3 s
# [560/608] Processing sub-560 ...
#     done in 2.0 s
# [561/608] Processing sub-561 ...
#     done in 2.1 s
# [562/608] Processing sub-562 ...
#     done in 2.1 s
# [563/608] Processing sub-563 ...
#     done in 2.2 s
# [564/608] Processing sub-564 ...
#     done in 2.2 s
# [565/608] Processing sub-565 ...
#     done in 2.1 s
# [566/608] Processing sub-566 ...
#     done in 2.2 s
# [567/608] Processing sub-567 ...
#     done in 2.1 s
# [568/608] Processing sub-568 ...
#     done in 2.2 s
# [569/608] Processing sub-569 ...
#     done in 2.2 s
# [570/608] Processing sub-570 ...
#     done in 2.1 s
# [571/608] Processing sub-571 ...
#     done in 2.1 s
# [572/608] Processing sub-572 ...
#     done in 2.1 s
# [573/608] Processing sub-573 ...
#     done in 2.2 s
# [574/608] Processing sub-574 ...
#     done in 2.1 s
# [575/608] Processing sub-575 ...
#     done in 2.2 s
# [576/608] Processing sub-576 ...
#     done in 2.1 s
# [577/608] Processing sub-577 ...
#     done in 2.5 s
# [578/608] Processing sub-578 ...
#     done in 2.3 s
# [579/608] Processing sub-579 ...
#     done in 2.1 s
# [580/608] Processing sub-580 ...
#     done in 2.1 s
# [581/608] Processing sub-581 ...
#     done in 2.2 s
# [582/608] Processing sub-582 ...
#     done in 2.1 s
# [583/608] Processing sub-583 ...
#     done in 2.2 s
# [584/608] Processing sub-584 ...
#     done in 2.1 s
# [585/608] Processing sub-585 ...
#     done in 2.2 s
# [586/608] Processing sub-586 ...
#     done in 2.2 s
# [587/608] Processing sub-587 ...
#     done in 2.1 s
# [588/608] Processing sub-588 ...
#     done in 2.2 s
# [589/608] Processing sub-589 ...
#     done in 2.1 s
# [590/608] Processing sub-590 ...
#     done in 2.1 s
# [591/608] Processing sub-591 ...
#     done in 2.1 s
# [592/608] Processing sub-592 ...
#     done in 2.1 s
# [593/608] Processing sub-593 ...
#     done in 2.2 s
# [594/608] Processing sub-594 ...
#     done in 2.1 s
# [595/608] Processing sub-595 ...
#     done in 2.1 s
# [596/608] Processing sub-596 ...
#     done in 2.2 s
# [597/608] Processing sub-597 ...
#     done in 2.2 s
# [598/608] Processing sub-598 ...
#     done in 2.1 s
# [599/608] Processing sub-599 ...
#     done in 2.1 s
# [600/608] Processing sub-600 ...
#     done in 2.1 s
# [601/608] Processing sub-601 ...
#     done in 2.2 s
# [602/608] Processing sub-602 ...
#     done in 2.2 s
# [603/608] Processing sub-603 ...
#     done in 2.1 s
# [604/608] Processing sub-604 ...
#     done in 2.1 s
# [605/608] Processing sub-605 ...
#     done in 2.0 s
# [606/608] Processing sub-606 ...
#     done in 2.2 s
# [607/608] Processing sub-607 ...
#     done in 2.1 s
# [608/608] Processing sub-608 ...
#     done in 2.2 s
# Finished remaining participants in 22.7 min
#   participant_id  age   condition  n_occipital_channels  n_posterior_channels  \
# 0        sub-001   60  EyesClosed                     3                    19
# 1        sub-001   60    EyesOpen                     3                    19
# 2        sub-002   67  EyesClosed                     3                    19
# 3        sub-002   67    EyesOpen                     3                    19
# 4        sub-003   44  EyesClosed                     3                    19
#
#                                   posterior_channels  n_epochs_kept  \
# 0  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             77
# 1  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             35
# 2  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             81
# 3  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             47
# 4  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...            107
#
#    alpha_power_8_12  posterior_alpha_sum_8_12  fooof_alpha_cf  fooof_alpha_pw  \
# 0        -10.257854                 -9.067168       10.109051        1.711548
# 1        -11.266725                 -9.949122       10.994871        0.382865
# 2        -10.221930                 -9.088553        9.204659        1.745596
# 3        -11.493045                -10.101173        8.467325        0.338656
# 4        -10.989451                 -9.893156       11.352306        1.386752
#
#    fooof_alpha_bw  fooof_r2  fooof_error
# 0        1.850375  0.958282     0.085840
# 1        3.216583  0.973884     0.050167
# 2        2.435050  0.966918     0.075781
# 3        1.327376  0.977051     0.043199
# 4        1.756418  0.967573     0.067330

# %%
features.groupby("condition")[
    ["alpha_power_8_12", "posterior_alpha_sum_8_12"]
].describe()
# Out:
#            alpha_power_8_12                                             \
#                       count       mean       std        min        25%
# condition
# EyesClosed            604.0 -10.733910  0.592002 -12.100806 -11.167402
# EyesOpen              591.0 -11.351595  0.402918 -12.143214 -11.649687
#
#                                            posterior_alpha_sum_8_12  \
#                   50%       75%        max                    count
# condition
# EyesClosed -10.677601 -10.27047  -9.480998                    604.0
# EyesOpen   -11.420396 -11.11035 -10.218024                    591.0
#
#                                                                             \
#                  mean       std        min        25%        50%       75%
# condition
# EyesClosed  -9.509320  0.565099 -10.887405  -9.932720  -9.459034 -9.061417
# EyesOpen   -10.084499  0.413192 -10.935661 -10.402913 -10.145948 -9.817239
#
#
#                  max
# condition
# EyesClosed -8.344808
# EyesOpen   -8.851775

# %%
posterior_wide = (
    features
    .pivot_table(
        index="participant_id",
        columns="condition",
        values="posterior_alpha_sum_8_12"
    )
    .reset_index()
)

posterior_wide = posterior_wide.dropna(subset=["EyesClosed", "EyesOpen"]).copy()

posterior_wide["posterior_alpha_diff_ec_minus_eo"] = (
    posterior_wide["EyesClosed"] - posterior_wide["EyesOpen"]
)

posterior_wide["correct_simple_baseline"] = (
    posterior_wide["EyesClosed"] > posterior_wide["EyesOpen"]
)

accuracy = posterior_wide["correct_simple_baseline"].mean()

print(f"Simple posterior-alpha baseline accuracy: {accuracy:.3f}")
print(f"Participants included: {len(posterior_wide)}")

display(posterior_wide.head())
# Out:
# Simple posterior-alpha baseline accuracy: 0.958
# Participants included: 590
# condition participant_id  EyesClosed   EyesOpen  \
# 0                sub-001   -9.067168  -9.949122
# 1                sub-002   -9.088553 -10.101173
# 2                sub-003   -9.893156 -10.685098
# 3                sub-004   -8.827828 -10.386710
# 4                sub-005   -9.338288 -10.225608
#
# condition  posterior_alpha_diff_ec_minus_eo  correct_simple_baseline
# 0                                  0.881954                     True
# 1                                  1.012621                     True
# 2                                  0.791942                     True
# 3                                  1.558882                     True
# 4                                  0.887320                     True

# %% [markdown]
# #### Inspect and save

# %%
print(features.shape)
print(features.isna().sum())
print(features.head(10))
features.to_csv(out_file, index=False)
print(f"Saved features to: {out_file}")
# Out:
# (1216, 14)
# participant_id               0
# age                          0
# condition                    0
# n_occipital_channels         0
# n_posterior_channels         0
# posterior_channels           0
# n_epochs_kept                0
# alpha_power_8_12            21
# posterior_alpha_sum_8_12    21
# fooof_alpha_cf              92
# fooof_alpha_pw              92
# fooof_alpha_bw              92
# fooof_r2                    21
# fooof_error                 21
# dtype: int64
#   participant_id  age   condition  n_occipital_channels  n_posterior_channels  \
# 0        sub-001   60  EyesClosed                     3                    19
# 1        sub-001   60    EyesOpen                     3                    19
# 2        sub-002   67  EyesClosed                     3                    19
# 3        sub-002   67    EyesOpen                     3                    19
# 4        sub-003   44  EyesClosed                     3                    19
# 5        sub-003   44    EyesOpen                     3                    19
# 6        sub-004   24  EyesClosed                     3                    19
# 7        sub-004   24    EyesOpen                     3                    19
# 8        sub-005   48  EyesClosed                     3                    19
# 9        sub-005   48    EyesOpen                     3                    19
#
#                                   posterior_channels  n_epochs_kept  \
# 0  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             77
# 1  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             35
# 2  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             81
# 3  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             47
# 4  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...            107
# 5  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             22
# 6  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             80
# 7  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             49
# 8  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             91
# 9  P7,P3,Pz,P4,P8,PO9,O1,Oz,O2,PO10,P5,P1,P2,P6,P...             16
#
#    alpha_power_8_12  posterior_alpha_sum_8_12  fooof_alpha_cf  fooof_alpha_pw  \
# 0        -10.257854                 -9.067168       10.109051        1.711548
# 1        -11.266725                 -9.949122       10.994871        0.382865
# 2        -10.221930                 -9.088553        9.204659        1.745596
# 3        -11.493045                -10.101173        8.467325        0.338656
# 4        -10.989451                 -9.893156       11.352306        1.386752
# 5        -11.924012                -10.685098       11.530868        0.243168
# 6         -9.980468                 -8.827828       10.405873        2.325008
# 7        -11.574404                -10.386710       10.348478        0.240066
# 8        -10.728284                 -9.338288       10.190261        1.470827
# 9        -11.493758                -10.225608       10.312360        0.673380
#
#    fooof_alpha_bw  fooof_r2  fooof_error
# 0        1.850375  0.958282     0.085840
# 1        3.216583  0.973884     0.050167
# 2        2.435050  0.966918     0.075781
# 3        1.327376  0.977051     0.043199
# 4        1.756418  0.967573     0.067330
# 5        1.385391  0.957140     0.049690
# 6        1.334469  0.982107     0.062080
# 7        1.000000  0.979661     0.037819
# 8        1.816293  0.983473     0.049162
# 9        1.135308  0.870754     0.065787
# Saved features to: C:\Users\maria\Desktop\EEG-special-course\data_processed\features_pre_ses1_with_posterior.csv

# %% [markdown]
# #### Dataset Validation

# %% [markdown]
# ##### Check that EO and EC counts are balanced

# %%
features["condition"].value_counts()
# Out:
# condition
# EyesClosed    608
# EyesOpen      608
# Name: count, dtype: int64

# %% [markdown]
# ##### Check whether EC alpha is generally higher than EO alpha

# %%
features.groupby("condition")["alpha_power_8_12"].describe()
# Out:
#             count       mean       std        min        25%        50%  \
# condition
# EyesClosed  604.0 -10.733910  0.592002 -12.100806 -11.167402 -10.677601
# EyesOpen    591.0 -11.351595  0.402918 -12.143214 -11.649687 -11.420396
#
#                  75%        max
# condition
# EyesClosed -10.27047  -9.480998
# EyesOpen   -11.11035 -10.218024

# %% [markdown]
# ##### Check whether the EO/EC effect is present in our sample

# %%
import matplotlib.pyplot as plt

features.boxplot(column="alpha_power_8_12", by="condition")
plt.title("Alpha power (8–12 Hz) by condition")
plt.suptitle("")
plt.ylabel("log10 alpha power")
plt.show()
